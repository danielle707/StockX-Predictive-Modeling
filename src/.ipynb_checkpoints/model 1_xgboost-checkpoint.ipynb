# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

from sklearn.model_selection import train_test_split

import xgboost as xgb
from xgboost import plot_tree
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import  r2_score,mean_absolute_error,mean_squared_log_error,median_absolute_error,explained_variance_score
from sklearn.metrics import mean_squared_error

from sklearn.svm import SVR
from sklearn.svm import LinearSVR
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import learning_curve
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("../data/StockX-Data-Consolidated.csv")

# %%
# Train-Test Splitting
data.rename(columns = lambda x: x.replace(' ', '_'), inplace=True)
x = data.drop(["Pct_change",'Sale_Price','Unnamed:_0'], axis=1)
y = data["Pct_change"]
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3)

# %% [markdown]
# ## Xgboost before cross-validation: finding benchmark

# %%
data_dmatrix = xgb.DMatrix(data=x,label=y)
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)
# Out:
# //anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# //anaconda3/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %%
params = {
    # Parameters that we are going to tune.
    'max_depth':5,
    'min_child_weight': 1,
    'eta':.3,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:squarederror',
}

# %%
params['eval_metric'] = "rmse"
num_boost_round = 900

# %%
cv_results = xgb.cv(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    seed=42,
    nfold=5,
    metrics={'rmse'},
    early_stopping_rounds=10
)

# %%
cv_results['test-rmse-mean'].min()
# Out:
# 0.20667500000000003

# %% [markdown]
# #### *Training set cv_result rmse: 0.2102*

# %% [markdown]
# ## Cross-validation and Hyperparamter tuning
# ### 1. Grid search for max_depth and min_child_weight

# %%
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(5,9)
    for min_child_weight in range(5,10)
]

# %%
min_rmse = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'rmse'},
        early_stopping_rounds=10
    )
    # Update best MAE
    mean_rmse = cv_results['test-rmse-mean'].min()
    boost_rounds = cv_results['test-rmse-mean'].argmin()
    print("\tRMSE {} for {} rounds".format(mean_rmse, boost_rounds))
    if mean_rmse < min_rmse:
        min_rmse = mean_rmse
        best_params = (max_depth,min_child_weight)
# Out:
# CV with max_depth=5, min_child_weight=5
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
# 	RMSE 0.22725399999999998 for 151 rounds
# CV with max_depth=5, min_child_weight=6
# 	RMSE 0.2288506 for 151 rounds
# CV with max_depth=5, min_child_weight=7
# 	RMSE 0.2300376 for 151 rounds
# CV with max_depth=5, min_child_weight=8
# 	RMSE 0.232885 for 151 rounds
# CV with max_depth=5, min_child_weight=9
# 	RMSE 0.23213979999999998 for 151 rounds
# CV with max_depth=6, min_child_weight=5
# 	RMSE 0.21415379999999998 for 150 rounds
# CV with max_depth=6, min_child_weight=6
# 	RMSE 0.21627999999999997 for 151 rounds
# CV with max_depth=6, min_child_weight=7
# 	RMSE 0.2184806 for 151 rounds
# CV with max_depth=6, min_child_weight=8
# 	RMSE 0.21984900000000002 for 151 rounds
# CV with max_depth=6, min_child_weight=9
# 	RMSE 0.22065640000000003 for 151 rounds
# CV with max_depth=7, min_child_weight=5
# 	RMSE 0.20809219999999998 for 150 rounds
# CV with max_depth=7, min_child_weight=6
# 	RMSE 0.20935160000000003 for 150 rounds
# CV with max_depth=7, min_child_weight=7
# 	RMSE 0.21172339999999998 for 151 rounds
# CV with max_depth=7, min_child_weight=8
# 	RMSE 0.21312760000000003 for 151 rounds
# CV with max_depth=7, min_child_weight=9
# 	RMSE 0.213299 for 151 rounds
# CV with max_depth=8, min_child_weight=5
# 	RMSE 0.20360740000000002 for 151 rounds
# CV with max_depth=8, min_child_weight=6
# 	RMSE 0.2067514 for 151 rounds
# CV with max_depth=8, min_child_weight=7
# 	RMSE 0.2078876 for 151 rounds
# CV with max_depth=8, min_child_weight=8
# 	RMSE 0.208949 for 151 rounds
# CV with max_depth=8, min_child_weight=9
# 	RMSE 0.2084276 for 151 rounds

# %%
print("Best params: {}, {}, RMSE: {}".format(best_params[0], best_params[1], min_rmse))
# Out:
# Best params: 8, 5, RMSE: 0.20360740000000002

# %% [markdown]
# #### *Update max_depth and min_child_weight hyperparameter*

# %%
params['max_depth'] = 8
params['min_child_weight'] = 5

# %% [markdown]
# ### 2. Grid Search for subsample and colsample_bytree (shrinkage parameters)

# %%
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]

# %%
min_rmse = float("Inf")
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed = 42,
        nfold=5,
        metrics={'rmse'},
        early_stopping_rounds=10
    )
    # Update best score
    mean_rmse = cv_results['test-rmse-mean'].min()
    boost_rounds = cv_results['test-rmse-mean'].argmin()
    print("\tRMSE {} for {} rounds".format(mean_rmse, boost_rounds))
    if mean_rmse < min_rmse:
        min_rmse = mean_rmse
        best_params = (subsample,colsample)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_rmse))
# Out:
# CV with subsample=1.0, colsample=1.0
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
# 	RMSE 0.20360740000000002 for 151 rounds
# CV with subsample=1.0, colsample=0.9
# 	RMSE 0.2048026 for 150 rounds
# CV with subsample=1.0, colsample=0.8
# 	RMSE 0.20706499999999997 for 151 rounds
# CV with subsample=1.0, colsample=0.7
# 	RMSE 0.20884160000000002 for 150 rounds
# CV with subsample=0.9, colsample=1.0
# 	RMSE 0.20797179999999998 for 117 rounds
# CV with subsample=0.9, colsample=0.9
# 	RMSE 0.205952 for 146 rounds
# CV with subsample=0.9, colsample=0.8
# 	RMSE 0.2096554 for 151 rounds
# CV with subsample=0.9, colsample=0.7
# 	RMSE 0.2114162 for 151 rounds
# CV with subsample=0.8, colsample=1.0
# 	RMSE 0.2060944 for 151 rounds
# CV with subsample=0.8, colsample=0.9
# 	RMSE 0.20838320000000002 for 151 rounds
# CV with subsample=0.8, colsample=0.8
# 	RMSE 0.2108078 for 151 rounds
# CV with subsample=0.8, colsample=0.7
# 	RMSE 0.21246 for 135 rounds
# CV with subsample=0.7, colsample=1.0
# 	RMSE 0.20941839999999998 for 147 rounds
# CV with subsample=0.7, colsample=0.9
# 	RMSE 0.2093614 for 146 rounds
# CV with subsample=0.7, colsample=0.8
# 	RMSE 0.210579 for 151 rounds
# CV with subsample=0.7, colsample=0.7
# 	RMSE 0.2133302 for 144 rounds
# Best params: 1.0, 1.0, MAE: 0.20360740000000002

# %%
params['subsample'] = 1.0
params['colsample_bytree'] = 1.0

# %% [markdown]
# ### 3. Grid Search for ETA

# %%
# %time

min_rmse = float("Inf")
best_params = None
for eta in [.5, .45, .4, .35, .3, .2, .1, .05]:
    print("CV with eta={}".format(eta))
    # We update our parameters
    params['eta'] = eta
    # Run and time CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics=['rmse'],
        early_stopping_rounds=10)
    # Update best score
    mean_rmse = cv_results['test-rmse-mean'].min()
    boost_rounds = cv_results['test-rmse-mean'].argmin()
    print("\tMAE {} for {} rounds\n".format(mean_rmse, boost_rounds))
    if mean_rmse < min_rmse:
        min_rmse = mean_rmse
        best_params = eta
print("Best params: {}, MAE: {}".format(best_params, min_rmse))
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.01 µs
# CV with eta=0.5
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
# 	MAE 0.2068438 for 124 rounds
#
# CV with eta=0.45
# 	MAE 0.2033274 for 151 rounds
#
# CV with eta=0.4
# 	MAE 0.206353 for 124 rounds
#
# CV with eta=0.35
# 	MAE 0.2056838 for 149 rounds
#
# CV with eta=0.3
# 	MAE 0.20360740000000002 for 151 rounds
#
# CV with eta=0.2
# 	MAE 0.20549219999999999 for 150 rounds
#
# CV with eta=0.1
# 	MAE 0.2143754 for 151 rounds
#
# CV with eta=0.05
# 	MAE 0.22297099999999997 for 151 rounds
#
# Best params: 0.45, MAE: 0.2033274

# %%
params['eta'] = .45

# %% [markdown]
# ## Results

# %% [markdown]
# #### - *Xgb parameters in hyperparameter tuning using cross validation*

# %%
params
{'colsample_bytree': 1.0,
 'eta': 0.45,
 'eval_metric': 'rmse',
 'max_depth': 8,
 'min_child_weight': 5,
 'objective': 'reg:squarederror',
 'subsample': 1.0}
# Out:
# {'colsample_bytree': 1.0,
#  'eta': 0.45,
#  'eval_metric': 'rmse',
#  'max_depth': 8,
#  'min_child_weight': 5,
#  'objective': 'reg:squarederror',
#  'subsample': 1.0}

# %% [markdown]
# #### - *Model Prediction using above parameters*

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)
# Out:
#
= xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")]
)
# Out:
# [0]	Test-rmse:0.98775
# [1]	Test-rmse:0.627106
# [2]	Test-rmse:0.426374
# [3]	Test-rmse:0.355472
# [4]	Test-rmse:0.295096
# [5]	Test-rmse:0.262543
# [6]	Test-rmse:0.251043
# [7]	Test-rmse:0.237327
# [8]	Test-rmse:0.229679
# [9]	Test-rmse:0.222598
# [10]	Test-rmse:0.220148
# [11]	Test-rmse:0.217662
# [12]	Test-rmse:0.214128
# [13]	Test-rmse:0.212877
# [14]	Test-rmse:0.212604
# [15]	Test-rmse:0.20961
# [16]	Test-rmse:0.209037
# [17]	Test-rmse:0.207994
# [18]	Test-rmse:0.208362
# [19]	Test-rmse:0.208432
# [20]	Test-rmse:0.208685
# [21]	Test-rmse:0.206825
# [22]	Test-rmse:0.205433
# [23]	Test-rmse:0.205306
# [24]	Test-rmse:0.205164
# [25]	Test-rmse:0.204641
# [26]	Test-rmse:0.204647
# [27]	Test-rmse:0.204648
# [28]	Test-rmse:0.204868
# [29]	Test-rmse:0.204999
# [30]	Test-rmse:0.204315
# [31]	Test-rmse:0.203612
# [32]	Test-rmse:0.203594
# [33]	Test-rmse:0.20337
# [34]	Test-rmse:0.203184
# [35]	Test-rmse:0.202896
# [36]	Test-rmse:0.202003
# [37]	Test-rmse:0.201796
# [38]	Test-rmse:0.201782
# [39]	Test-rmse:0.201606
# [40]	Test-rmse:0.201764
# [41]	Test-rmse:0.200418
# [42]	Test-rmse:0.200351
# [43]	Test-rmse:0.200331
# [44]	Test-rmse:0.200147
# [45]	Test-rmse:0.200202
# [46]	Test-rmse:0.200171
# [47]	Test-rmse:0.199715
# [48]	Test-rmse:0.199567
# [49]	Test-rmse:0.199564
# [50]	Test-rmse:0.199472
# [51]	Test-rmse:0.199187
# [52]	Test-rmse:0.199035
# [53]	Test-rmse:0.198655

# %%
y_pred = best_model.predict(dtest)

# %%
print('R²: %.4f' % r2_score(y_pred, y_test))
print("mse: %.4f" % mean_squared_error(y_pred, y_test))
print("rmse: %.4f" % np.sqrt(mean_squared_error(y_pred, y_test)))
# Out:
# R²: 0.9824
# mse: 0.0395
# rmse: 0.1987

# %%
best_model.save_model("my_model.model")

# %%
loaded_model = xgb.Booster()
loaded_model.load_model("my_model.model")
# And use it for predictions.
loaded_model.predict(dtest)
# Out:
# array([0.974396  , 0.23138842, 0.5939306 , ..., 2.3344667 , 0.25973728,
#        0.19720808], dtype=float32)

# %%
xgb.plot_importance(best_model)
plt.rcParams['figure.figsize'] = [10,8]
plt.show()

# %%
error = pd.DataFrame(y_test)
error["predict_y"] = y_pred
error["error"] = error["Pct_change"] - error["predict_y"]
error["error^2"] = error["error"]**2
error['ptg_error']=error["error"]/error["Pct_change"]
error.sort_values(by=['ptg_error'],ascending= False)[:50]
# Out:
#        Pct_change  predict_y     error   error^2  ptg_error
# 57936    0.000000  -0.004044  0.004044  0.000016        inf
# 50902   -0.004545   0.081393 -0.085939  0.007385  18.906528
# 66210   -0.004545   0.070050 -0.074596  0.005565  16.411035
# 95500   -0.004545   0.053980 -0.058525  0.003425  12.875518
# 93994   -0.004545   0.046794 -0.051340  0.002636  11.294737
# 57511   -0.004545   0.046463 -0.051009  0.002602  11.221893
